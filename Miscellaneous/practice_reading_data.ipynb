# %%
import pandas as pd
from spacepy import pycdf
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_hdf('../Data_Processed/Individual/psp/psp_unbinned_20180101_20241201.hf')
df.keys()
# Out:
# Index(['ssepoch', 'Epoch', 'bm', 'np', 'vp_m', 'Tp', 'sc_r',
#        'heliographicLatitude', 'heliographicLongitude'],
#       dtype='object')

# %%
plt.scatter((df['ssepoch']/ 3.154e+7)+1970, df['sc_r'], s = 1)
plt.yscale('log')

# %%
plt.scatter( df['sc_r'],df['heliographicLatitude'], s = 1)
print(df["sc_r"][0:25])
plt.xscale('log')
#plt.ylim([-45,45])
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# Name: sc_r, dtype: float64

# %%
df = pd.read_hdf('../Data_Processed/Individual/pioneer10/pioneer10_unbinned_19720101_19950901.hf')
df.keys()
plt.scatter((df['ssepoch']/ 3.154e+7)+1970, df['sc_r'], s = 1)
plt.yscale('log')
plt.show()
plt.scatter( df['sc_r'],df['heliographicLatitude'], s = 1)
print(df["sc_r"][0:25])
plt.xscale('log')
plt.show()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# Name: sc_r, dtype: float64

# %%
df = pd.read_hdf('../Data_Processed/Individual/psp/psp_binned.hf')
df.keys()
# Out:
# Index(['Tp_median', 'Tp_iqr_10', 'Tp_iqr_25', 'Tp_iqr_50', 'Tp_iqr_75',
#        'Tp_iqr_90', 'Tp_num', 'bm_median', 'bm_iqr_10', 'bm_iqr_25',
#        'bm_iqr_50', 'bm_iqr_75', 'bm_iqr_90', 'bm_num', 'np_median',
#        'np_iqr_10', 'np_iqr_25', 'np_iqr_50', 'np_iqr_75', 'np_iqr_90',
#        'np_num', 'vp_m_median', 'vp_m_iqr_10', 'vp_m_iqr_25', 'vp_m_iqr_50',
#        'vp_m_iqr_75', 'vp_m_iqr_90', 'vp_m_num', 'sc_r_median', 'sc_r_iqr_10',
#        'sc_r_iqr_25', 'sc_r_iqr_50', 'sc_r_iqr_75', 'sc_r_iqr_90', 'sc_r_num'],
#       dtype='object')

# %%
plt.scatter(df["sc_r_iqr_50"], df["bm_iqr_50"], s = 5)
plt.xscale('log')
plt.yscale("log")

# %%
df = pd.read_hdf("../Data_Processed/msc/all_spacecraft_binned_scaled.hf")
plt.scatter(df["sc_r_iqr_50"], df["bm_iqr_50"], s=7)
plt.vlines("")

plt.xscale("log")
plt.yscale("log")
